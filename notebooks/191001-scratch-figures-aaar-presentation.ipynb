# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
years = [2013, 2015, 2016, 2016, 2018, 2018]
dre = [0.11, 0.165, 0.11, 0.03, 0.06, 0.048]

# %%
fig, ax = plt.subplots(1,1, figsize=(4,5))
sns.set(style="ticks")
sns.set_context("talk")
ax = sns.boxplot(dre)
ax = sns.swarmplot(dre, color='black', edgecolor='black', size=15)
ax.set(xlabel='Globally averaged \n direct radiative effect (W m$^{-2}$)')
#        ylim=(-y_max * 0.05, y_max * 1.5), xlim=(-x_max * 0.05, x_max * 1.05))
# Out:
# [Text(0.5, 0, 'Globally averaged \n direct radiative effect (W m$^{-2}$)')]
